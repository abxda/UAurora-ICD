# %% [markdown]
# <a href="https://colab.research.google.com/github/abxda/UAurora-ICD/blob/main/Aurora_Ciencia_de_Datos_Semana_2.ipynb" target="_parent"><img src="https://colab.research.google.com/assets/colab-badge.svg" alt="Open In Colab"/></a>

# %% [markdown]
# #1. **Medidas de tendencia central**
#
# Las **medidas de tendencia central** son herramientas estadísticas fundamentales que nos permiten describir un conjunto de datos mediante un valor representativo. Existen tres medidas principales de tendencia central: la **media**, la **mediana** y la **moda**. Cada una de ellas captura una característica diferente de la distribución de los datos, y su utilidad depende de la naturaleza de los datos y del contexto de análisis.
#
# ---
#
# #### **1.1 Media Aritmética**
#
# - **Definición**: La **media** (o promedio) es el valor obtenido al sumar todos los datos y dividir el resultado por la cantidad total de datos. Representa el valor típico de una distribución cuando todos los datos contribuyen por igual.
#
#   $
#   \text{Media} = \frac{\sum_{i=1}^{n} x_i}{n}
#   $
#
#   Donde $x_i$ representa cada uno de los valores y $n$ es la cantidad de datos.
#
# - **Aplicación**:
#
#   - La media es útil cuando los datos son distribuidos de manera uniforme o no presentan valores atípicos (outliers) que distorsionen el promedio.
#   - Ejemplo: Si queremos calcular el salario promedio de un grupo de empleados o la calificación promedio de una clase, la media sería la medida más apropiada.
# - **Ventajas**:
#
#   - Utiliza todos los valores del conjunto de datos.
#   - Fácil de calcular y comprender.
# - **Limitaciones**:
#
#   - Es sensible a valores atípicos (outliers), que pueden distorsionar el valor de la media y no representar adecuadamente el conjunto de datos.
#
# **Cálculo de la Media Aritmética Paso a Paso**
#
# **Definición Matemática**:
# La **media aritmética** es el valor promedio de un conjunto de datos. Matemáticamente, la media de un conjunto de datos $ x_1, x_2, \dots, x_n $ se define como:
#
# $
# \text{Media} = \frac{1}{n} \sum_{i=1}^{n} x_i = \frac{x_1 + x_2 + x_3 + \dots + x_n}{n}
# $
#
# Donde:
#
# - $ n $ es la cantidad total de elementos en el conjunto de datos.
# - $ x_i $ representa cada uno de los valores de los datos, donde $ i $ es el índice que identifica a cada valor.
# - La suma $ \sum_{i=1}^{n} x_i $ representa la adición de todos los valores en el conjunto de datos.
#
# ---
#
# ### **Explicación Detallada del Código**
#
# 1. **Definir los datos**:
#
#   ```python
#   data = [85, 90, 78, 92, 88, 76, 95, 89]
#   ```
#
#   Aquí tenemos un conjunto de datos llamado `data`, que contiene las **calificaciones** de un grupo de estudiantes. Cada número en esta lista es un valor que corresponde a la calificación de un estudiante.
#
#   Si expresamos los datos usando la notación matemática, estos serían:
#   $
#   x_1 = 85, \quad x_2 = 90, \quad x_3 = 78, \quad x_4 = 92, \quad x_5 = 88, \quad x_6 = 76, \quad x_7 = 95, \quad x_8 = 89
#   $
#   Y el total de valores es \( n = 8 \), es decir, hay 8 estudiantes cuyas calificaciones estamos analizando.
#
# 2. **Calcular la media**:
#
#   ```python
#   media = np.mean(data)
#   ```
#
#   La función `np.mean(data)` toma todos los valores en la lista `data` y calcula la media aritmética siguiendo la fórmula descrita antes. El proceso paso a paso sería:
#
#   - Sumar todos los valores de las calificaciones:
#     $
#     \sum_{i=1}^{n} x_i = 85 + 90 + 78 + 92 + 88 + 76 + 95 + 89 = 693
#     $
#
#   - Dividir la suma entre el número total de calificaciones $ n = 8 $:
#
#     $
#     \text{Media} = \frac{693}{8} = 86.625
#     $
#
#
#   Por lo tanto, la media de las calificaciones es $ 86.625 $. Esto significa que el "promedio" de las calificaciones del grupo de estudiantes es de aproximadamente 86.63 (si redondeamos a dos decimales).
#
# 3. **Mostrar el resultado**:
#
#   ```python
#   print(f"La media de las calificaciones es: {media:.2f}")
#   ```
#
#   El código `print(f"La media de las calificaciones es: {media:.2f}")` imprime el resultado de la media en la consola, mostrando el valor con dos decimales. El formato `:.2f` asegura que el número se presente con dos lugares después del punto decimal.

# %%
import numpy as np
# Datos: Calificaciones de un grupo de estudiantes
data = [85, 90, 78, 92, 88, 76, 95, 89]
# Cálculo de la media
media = np.mean(data)
print(f"La media de las calificaciones es: {media:.2f}")
# Out:
# La media de las calificaciones es: 86.62

# %% [markdown]
# **Interpretación**:
#
# En este caso, la **media** nos indica que, si distribuimos las calificaciones de manera uniforme, cada estudiante tendría una calificación de 86.63. Este valor es útil para obtener una idea general de cómo se comporta el grupo en su conjunto. Sin embargo, es importante recordar que la media puede verse afectada por valores extremos (calificaciones muy altas o muy bajas).
#
# ---
#
# ### **Visualización** :
#
# Para comprender mejor la distribución de las calificaciones, podemos crear un gráfico que muestre las calificaciones individuales y la media.

# %%
import matplotlib.pyplot as plt
import numpy as np

# Calificaciones de los estudiantes
data = [85, 90, 78, 92, 88, 76, 95, 89]

# Calcular la media
media = np.mean(data)

# Visualización
plt.figure(figsize=(10,6))
plt.bar(range(1, len(data) + 1), data, color='lightblue', edgecolor='black')
plt.axhline(y=media, color='r', linestyle='dashed', linewidth=2, label=f'Media = {media:.2f}')
plt.xlabel('Estudiantes')
plt.ylabel('Calificaciones')
plt.title('Calificaciones de los estudiantes y la media')
plt.legend()
plt.grid(True)
plt.show()

# %% [markdown]
# Este cálculo de la media aritmética es fundamental para entender el comportamiento general de los datos, y es una de las medidas más comunes en estadística descriptiva. Si bien proporciona información valiosa, siempre debe considerarse en conjunto con otras medidas (como la mediana o la moda) para obtener una imagen completa de los datos, especialmente en situaciones donde puede haber valores extremos que influyan en la media.

# %% [markdown]
# Vamos a abordar la **debilidad** de la media frente a valores atípicos o extremos en el conjunto de datos. Un valor extremo puede influir desproporcionadamente en el cálculo de la media, distorsionando su representatividad. Para mostrar este efecto de manera gráfica y clara, agregaremos un valor extremo muy alto a las calificaciones y compararemos su impacto en la media.
#
# ### **Gráfica mostrando el efecto de un valor extremo**:
#
# Vamos a modificar el conjunto de datos original agregando un valor extremo (por ejemplo, 300) y luego compararemos el efecto de este valor en la media.

# %%
import matplotlib.pyplot as plt
import numpy as np

# Calificaciones de los estudiantes con un valor extremo
data_con_valor_extremo = [85, 90, 78, 92, 88, 76, 95, 89, 300]  # Añadimos el valor extremo de 300

# Cálculo de la media con y sin el valor extremo
media_sin_extremo = np.mean([85, 90, 78, 92, 88, 76, 95, 89])  # Media sin el valor extremo
media_con_extremo = np.mean(data_con_valor_extremo)  # Media con el valor extremo

# Visualización
plt.figure(figsize=(12, 6))

# Gráfico con las calificaciones originales
plt.subplot(1, 2, 1)  # Primera subgráfica: datos originales
plt.bar(range(1, 9), [85, 90, 78, 92, 88, 76, 95, 89], color='lightblue', edgecolor='black')
plt.axhline(y=media_sin_extremo, color='r', linestyle='dashed', linewidth=2, label=f'Media = {media_sin_extremo:.2f}')
plt.xlabel('Estudiantes')
plt.ylabel('Calificaciones')
plt.title('Sin valor extremo')
plt.legend()
plt.grid(True)

# Gráfico con el valor extremo añadido
plt.subplot(1, 2, 2)  # Segunda subgráfica: con el valor extremo
plt.bar(range(1, 10), data_con_valor_extremo, color='lightcoral', edgecolor='black')
plt.axhline(y=media_con_extremo, color='r', linestyle='dashed', linewidth=2, label=f'Media = {media_con_extremo:.2f}')
plt.xlabel('Estudiantes')
plt.ylabel('Calificaciones')
plt.title('Con valor extremo (300)')
plt.legend()
plt.grid(True)

plt.tight_layout()
plt.show()

# %% [markdown]
# **Explicación del Código**:
#
# 1. **Datos**: Hemos modificado el conjunto original de calificaciones añadiendo un valor extremo de **300**. Este valor es significativamente más alto que el resto de las calificaciones, lo que debería tener un impacto notable en la media.
#
# 2. **Cálculo de la media**:
#
#   - **Sin valor extremo**: Calculamos la media de las calificaciones originales, que es 86.625.
#   - **Con valor extremo**: Calculamos la media de las calificaciones después de agregar el valor extremo, que es mucho mayor.
# 3. **Visualización**:
#
#   - **Primera gráfica**: Muestra las calificaciones originales sin el valor extremo. La línea roja discontinua indica la media sin el valor extremo (86.63).
#   - **Segunda gráfica**: Muestra las calificaciones con el valor extremo. Aquí se observa cómo la **media** ha aumentado drásticamente debido a la inclusión del valor 300.
#
# ### **Interpretación de los Resultados**:
#
# - **Sin el valor extremo**: La media aritmética de las calificaciones originales es de 86.63, lo que da una buena idea del desempeño promedio del grupo.
#
# - **Con el valor extremo**: La inclusión de un valor atípico tan alto como 300 ha elevado la media a **110.33**, lo cual no representa adecuadamente las calificaciones típicas del grupo. La mayoría de las calificaciones siguen siendo cercanas al rango 70-90, pero la media ha sido distorsionada por este único valor.
#
#
# Este ejemplo demuestra una de las **limitaciones de la media**: es **sensible a valores atípicos**. En casos donde hay valores extremos, la **mediana** sería una medida más representativa, ya que no se ve afectada por estos valores de la misma forma que la media.

# %% [markdown]
# **1.2 Mediana**
#
# - **Definición**: La **mediana** es el valor que se encuentra en el centro de un conjunto de datos ordenado. Si el número de datos es impar, la mediana es el valor central; si es par, la mediana es el promedio de los dos valores centrales. A diferencia de la media, la mediana no se ve afectada por valores atípicos y es una mejor medida de tendencia central en distribuciones asimétricas.
#
#   Matemáticamente, la mediana se define como:
#
#   1. Ordenar el conjunto de datos de menor a mayor.
#   2. Si $ n $ (el número de datos) es impar, la mediana es el valor en la posición $ \frac{n+1}{2} $.
#   3. Si $ n $ es par, la mediana es el promedio de los valores en las posiciones $ \frac{n}{2} $ y $ \frac{n}{2} + 1 $.
#
#   Por ejemplo, si \( n \) es 7:
#
#   $ \text{Mediana} = x_{\frac{n+1}{2}} = x_{\frac{7+1}{2}} = x_4 $
#
#   Y si \( n \) es 8:
#
#   $ \text{Mediana} = \frac{x_{\frac{n}{2}} + x_{\frac{n}{2}+1}}{2} = \frac{x_4 + x_5}{2} $
#
# - **Aplicación**:
#
#   - La mediana es útil cuando los datos tienen **valores atípicos** o están **distribuidos de manera asimétrica**. Por ejemplo, para calcular el valor típico de los ingresos en una población donde unos pocos individuos ganan mucho más que el resto, la mediana es una mejor representación del ingreso "típico" que la media.
#
#   - Ejemplo: Si queremos calcular la calificación mediana en una clase donde un estudiante ha tenido una calificación extraordinariamente baja o alta, la mediana sería más representativa del rendimiento general.
#
# - **Ventajas**:
#
#   - No es afectada por valores atípicos o extremos.
#   - Representa mejor el "centro" en distribuciones asimétricas.
# - **Limitaciones**:
#
#   - No utiliza toda la información del conjunto de datos, solo los valores centrales.
#   - Puede no ser tan intuitiva como la media, especialmente cuando los datos son muy dispersos.
#
# ---
#
# ### **Cálculo de la Mediana Paso a Paso**
#
# 1. **Definir los datos**:
#
#   ```python
#   data = [85, 90, 78, 92, 88, 76, 95, 89]
#   ```
#
#   Este es el mismo conjunto de datos que usamos para la media, que contiene las calificaciones de un grupo de estudiantes.
#
# 2. **Ordenar los datos**:
#
#   ```python
#   data_ordenada = sorted(data)
#   ```
#
#   Al ordenar el conjunto, obtenemos:
#
#   ```
#   [76, 78, 85, 88, 89, 90, 92, 95]
#   ```
#
# 3. **Calcular la mediana**:
#
#   Como hay 8 valores (un número par), tomamos los dos valores centrales (el cuarto y el quinto) y calculamos su promedio:
#
#   $
#   \text{Mediana} = \frac{88 + 89}{2} = 88.5
#   $
#
#   En Python, podemos calcularlo así:
#
#   ```python
#   mediana = np.median(data)
#   ```
#
# 4. **Mostrar el resultado**:
#
#   ```python
#   print(f"La mediana de las calificaciones es: {mediana:.2f}")
#   ```
#
#   El valor de la mediana es 88.5, lo que indica que la calificación central de este grupo de estudiantes, cuando las calificaciones se ordenan de menor a mayor, está cerca de 88.5.

# %%
data = [85, 90, 78, 92, 88, 76, 95, 89]
data_ordenada = sorted(data)
print(data_ordenada)
mediana = np.median(data)
print(f"La mediana de las calificaciones es: {mediana:.2f}")
# Out:
# [76, 78, 85, 88, 89, 90, 92, 95]
# La mediana de las calificaciones es: 88.50

# %% [markdown]
# **Visualización**:
#
# Vamos a crear una gráfica que muestre la distribución de las calificaciones y marque la mediana.

# %%
import matplotlib.pyplot as plt
import numpy as np

# Calificaciones de los estudiantes
data = [85, 90, 78, 92, 88, 76, 95, 89]
mediana = np.median(data)

# Visualización
plt.figure(figsize=(10,6))
plt.bar(range(1, len(data) + 1), sorted(data), color='lightblue', edgecolor='black')
plt.axhline(y=mediana, color='r', linestyle='dashed', linewidth=2, label=f'Mediana = {mediana:.2f}')
plt.xlabel('Estudiantes')
plt.ylabel('Calificaciones')
plt.title('Calificaciones de los estudiantes y la mediana')
plt.legend()
plt.grid(True)
plt.show()

# %% [markdown]
# **Comparación con la Media**:
#
# Vamos a comparar la media y la mediana cuando agregamos un valor atípico (por ejemplo, una calificación extremadamente alta de 300):

# %%
data_con_valor_extremo = [85, 90, 78, 92, 88, 76, 95, 89, 300]

# Calcular la media y la mediana con el valor extremo
media_con_extremo = np.mean(data_con_valor_extremo)
mediana_con_extremo = np.median(data_con_valor_extremo)

print(f"Media con valor extremo: {media_con_extremo:.2f}")
print(f"Mediana con valor extremo: {mediana_con_extremo:.2f}")
# Out:
# Media con valor extremo: 110.33
# Mediana con valor extremo: 89.00

# %% [markdown]
# - **Interpretación**:
#   - La **media** aumenta considerablemente debido al valor extremo.
#   - La **mediana** permanece mucho más estable, ya que no está influenciada por valores extremos.
#
# Esto muestra cómo la mediana es una mejor medida cuando tenemos valores atípicos o distribuciones sesgadas.
#
# ---
#
# La mediana es una medida robusta de tendencia central, especialmente útil cuando los datos contienen valores atípicos o están distribuidos de forma asimétrica. Aunque no toma en cuenta toda la información del conjunto de datos como la media, ofrece una representación más fiel del valor "típico" en muchas situaciones.

# %% [markdown]
# **1.3 Moda**
#
# - **Definición**: La **moda** es el valor o los valores que aparecen con mayor frecuencia en un conjunto de datos. Un conjunto de datos puede tener:
#
#   - Una única moda (**unimodal**), si solo un valor se repite más que los demás.
#   - Dos modas (**bimodal**), si hay dos valores con la misma frecuencia más alta.
#   - Más de dos modas (**multimodal**), si varios valores se repiten con la misma frecuencia máxima.
#   - Si ningún valor se repite, se dice que el conjunto de datos no tiene moda.
#
#   A diferencia de la media y la mediana, la moda puede aplicarse tanto a variables numéricas como categóricas, lo que la hace útil para datos cualitativos.
#
# - **Aplicación**:
#
#   - La moda es especialmente útil para identificar el valor más frecuente en conjuntos de datos categóricos o discretos, como encuestas, donde es importante saber la opción más elegida.
#   - Ejemplo: Si estamos analizando las preferencias de colores en una encuesta, la moda nos indicaría el color que fue seleccionado con más frecuencia.
# - **Ventajas**:
#
#   - Es la **única medida** de tendencia central aplicable a datos categóricos (como colores, categorías, o elecciones).
#   - **Fácil de calcular** e interpretar en conjuntos de datos pequeños o categóricos.
# - **Limitaciones**:
#
#   - Puede no ser representativa en distribuciones **uniformes** (donde no hay un valor que se repita más) o en distribuciones **multimodales** (con más de una moda).
#   - No siempre refleja el centro de la distribución, especialmente en distribuciones numéricas con valores únicos.
#
# ---
#
# ### **Cálculo de la Moda Paso a Paso**
#
# 1. **Definir los datos**:
#
#   ```python
#   data = [85, 90, 78, 92, 88, 76, 95, 89, 85]
#   ```
#
#   En este conjunto de datos tenemos una repetición del valor 85, que aparece dos veces.
#
# 2. **Calcular la moda**:
#
#   Utilizamos `scipy.stats.mode` para calcular la moda:
#
#   ```python
#   from scipy import stats
#
#   moda = stats.mode(data)
#   print(f"La moda es: {moda.mode} y aparece {moda.count} veces")
#   ```
#
#   Este código devuelve que la moda es **85** y que aparece **2 veces**.
#
# 3. **Interpretación**:
#
#   La moda nos indica que la calificación más frecuente entre los estudiantes es **85**, lo que significa que **dos estudiantes** obtuvieron esta calificación.
#
#
# ---

# %%
data = [85, 90, 78, 92, 88, 76, 95, 89, 85]
from scipy import stats

moda = stats.mode(data)
print(f"La moda es: {moda.mode} y aparece {moda.count} veces")
# Out:
# La moda es: 85 y aparece 2 veces

# %% [markdown]
# **Medidas de Tendencia Central Visualizadas**
#
# Para visualizar mejor la distribución de los datos y las tres medidas de tendencia central (media, mediana y moda), podemos graficarlas juntas:

# %%
import matplotlib.pyplot as plt
import numpy as np
from scipy import stats

# Conjunto de datos
data = [85, 90, 78, 92, 88, 76, 95, 89, 85]

# Cálculo de medidas
media = np.mean(data)
mediana = np.median(data)
moda = stats.mode(data)

# Gráfico de barras
plt.figure(figsize=(10,6))
plt.bar(range(1, len(data)+1), sorted(data), color='lightblue', edgecolor='black')

# Añadir líneas para la media, mediana y moda
plt.axhline(y=media, color='r', linestyle='dashed', linewidth=2, label=f'Media = {media:.2f}')
plt.axhline(y=mediana, color='g', linestyle='dashed', linewidth=2, label=f'Mediana = {mediana:.2f}')
plt.axhline(y=moda.mode, color='b', linestyle='dashed', linewidth=2, label=f'Moda = {moda.mode}')

# Etiquetas y leyenda
plt.title('Distribución de Calificaciones: Media, Mediana y Moda', fontsize=14)
plt.xlabel('Estudiantes', fontsize=12)
plt.ylabel('Calificaciones', fontsize=12)
plt.legend()
plt.grid(True)

# Mostrar gráfico
plt.show()

# %% [markdown]
# # 2. **Medidas de Dispersión**
#
# ### **Teoría General**
#
# Las **medidas de dispersión** son fundamentales en el análisis de datos porque nos permiten entender **cuán dispersos o agrupados** están los valores de un conjunto de datos alrededor de una medida de tendencia central (como la media). Si bien las medidas de tendencia central (como la media, la mediana y la moda) nos dan una idea del valor "típico" o "central" de un conjunto de datos, las medidas de dispersión nos indican **cómo varían** esos datos.
#
# En términos simples, las medidas de dispersión responden preguntas como:
#
# - ¿Los valores están muy dispersos o concentrados alrededor de la media?
# - ¿Existen diferencias significativas entre los valores más altos y más bajos?
#
# Entre las principales medidas de dispersión se encuentran:
#
# ### 2.1 **Varianza**
#
# - **Definición**: La **varianza** es una medida que refleja el promedio de las diferencias cuadráticas entre cada valor del conjunto de datos y la media. Es una forma de cuantificar **cuánto se alejan los datos de la media**. Cuanto mayor sea la varianza, más dispersos estarán los datos. Se mide en unidades cuadradas, lo que la hace difícil de interpretar directamente en comparación con los datos originales.
#
#   Matemáticamente, la varianza se define como:
#
#   $
#   \text{Varianza} = \frac{\sum_{i=1}^{n} (x_i - \text{Media})^2}{n}
#   $
#
#   Donde:
#
#   - $x_i$ son los valores individuales del conjunto de datos.
#   - **Media** es el promedio de todos los valores.
#   - **n** es el número total de datos.
# - **Aplicación**:
#
#   La varianza es útil cuando queremos cuantificar cuán "alejados" están los valores de la media, lo que nos proporciona una idea de la **variabilidad** dentro del conjunto de datos. Por ejemplo, en un grupo de estudiantes, si las calificaciones tienen una varianza baja, significa que la mayoría tiene calificaciones cercanas al promedio, pero si la varianza es alta, las calificaciones están muy dispersas (algunos estudiantes tienen notas mucho más altas o más bajas que la media).
#
# - **Ventajas**:
#
#   - Toma en cuenta **todos los valores** del conjunto de datos.
#   - Es útil en muchos contextos estadísticos, especialmente en pruebas de hipótesis y modelos de regresión.
# - **Limitaciones**:
#
#   - Se mide en **unidades cuadradas**, lo que puede hacerla menos intuitiva para interpretar en comparación con los datos originales.
#
# ### 2.2 **Desviación Estándar**
#
# - **Definición**: La **desviación estándar** es la raíz cuadrada de la varianza. Al ser la raíz cuadrada, devuelve las unidades de medida a las mismas unidades que los datos originales, lo que la hace más **fácil de interpretar**. Al igual que la varianza, mide la **dispersión** de los datos alrededor de la media.
#
#   La desviación estándar se calcula como:
#
#   $
#   \text{Desviación Estándar} = \sqrt{\text{Varianza}} = \sqrt{\frac{\sum_{i=1}^{n} (x_i - \text{Media})^2}{n}}
#   $
#
#   Es decir, es una medida que nos indica **en promedio cuánto se desvía cada valor de la media**.
#
# - **Aplicación**:
#
#   La desviación estándar se utiliza comúnmente en estudios de análisis de datos porque es fácil de interpretar en el contexto de los valores originales. Si la desviación estándar es **baja**, significa que la mayoría de los datos están cerca de la media; si es **alta**, indica que los datos están muy dispersos.
#
#   Por ejemplo, en un análisis de salarios de empleados, si la desviación estándar es alta, algunos empleados ganan mucho más o mucho menos que el promedio.
#
# - **Ventajas**:
#
#   - Es más fácil de interpretar que la varianza, ya que está en las mismas unidades que los datos originales.
#   - Útil para evaluar la **variabilidad** en comparación con la media en distribuciones simétricas.
# - **Limitaciones**:
#
#   - Al igual que la varianza, **es sensible a valores atípicos**. Un solo valor muy alto o bajo puede aumentar considerablemente la desviación estándar.
#
# ### 2.3 **Rango**
#
# - **Definición**: El **rango** es la diferencia entre el valor más alto y el más bajo en un conjunto de datos. Es la medida de dispersión más sencilla, y nos da una idea rápida de la **amplitud** de los datos.
#
#   Matemáticamente, se expresa como:
#
#   $
#   \text{Rango} = \text{Valor Máximo} - \text{Valor Mínimo}
#   $
#
#   Aunque el rango es fácil de calcular, **solo utiliza dos valores** del conjunto de datos (el mínimo y el máximo), por lo que no proporciona información sobre cómo se distribuyen los demás valores.
#
# - **Aplicación**:
#
#   El rango es útil cuando necesitamos una idea rápida del **intervalo** en el que caen todos los valores. Por ejemplo, si estamos analizando las temperaturas diarias de una ciudad, el rango nos indicará la diferencia entre el día más frío y el día más caluroso.
#
# - **Ventajas**:
#
#   - Es **fácil de calcular** y entender.
#   - Nos da una idea rápida de la **amplitud** de los datos.
# - **Limitaciones**:
#
#   - Solo tiene en cuenta los **valores extremos**, ignorando completamente cómo se distribuyen el resto de los valores.
#   - Es **muy sensible a valores atípicos**. Un valor extremadamente alto o bajo puede distorsionar el rango.
#
# ---
#
# ### **Cálculo de las Medidas de Dispersión en Python**
#
# Para ilustrar mejor cómo calcular estas medidas de dispersión, utilicemos el siguiente conjunto de datos, que corresponde a las calificaciones de un grupo de estudiantes:

# %%
import numpy as np

# Conjunto de datos: calificaciones de un grupo de estudiantes
data = [85, 90, 78, 92, 88, 76, 95, 89, 85]

# Cálculo de la varianza
varianza = np.var(data)
print(f"Varianza: {varianza:.2f}")

# Cálculo de la desviación estándar
desviacion_estandar = np.std(data)
print(f"Desviación Estándar: {desviacion_estandar:.2f}")

# Cálculo del rango
rango = np.max(data) - np.min(data)
print(f"Rango: {rango}")
# Out:
# Varianza: 34.47
# Desviación Estándar: 5.87
# Rango: 19

# %% [markdown]
# **Interpretación de los Resultados**:
#
# 1. **Varianza**: Mide cuánto se alejan, en promedio, las calificaciones de la media. Si la varianza es alta, significa que las calificaciones están muy dispersas. En nuestro ejemplo, la varianza es 34.47, lo que indica que las calificaciones no están tan concentradas alrededor de la media.
#
# 2. **Desviación Estándar**: Al ser la raíz cuadrada de la varianza, nos indica en **promedio cuán lejos está cada valor de la media** en las mismas unidades que los datos originales (calificaciones). Por ejemplo, si la desviación estándar es 5.87, significa que, en promedio, las calificaciones varían en 5.87 puntos respecto a la media.
#
# 3. **Rango**: El rango mide la **amplitud total** de las calificaciones. Si el rango es 19 (la diferencia entre 95 y 76), indica que la calificación más alta es 19 puntos mayor que la más baja.
#
# ---
#
# Las **medidas de dispersión** son esenciales para complementar las **medidas de tendencia central**. Mientras que la media, la mediana y la moda nos dicen cuál es el valor típico de un conjunto de datos, las medidas de dispersión nos dicen **cuán alejados o cercanos** están los datos entre sí y de ese valor típico. Con la varianza y la desviación estándar, obtenemos una idea precisa de la **variabilidad** del conjunto de datos, mientras que el rango nos proporciona una **visión rápida** de la amplitud de los valores.

# %% [markdown]
# #### **2.4 Visualización e Interpretación de las Medidas de Dispersión**
#
# Para comprender mejor el sentido de las **medidas de dispersión** (varianza, desviación estándar y rango), es útil visualizar cómo se calculan paso a paso y observar su impacto en la distribución de los datos a través de gráficos. A continuación, desarrollaremos estos conceptos en un contexto práctico.
#
# #### **Cálculo y Explicación Paso a Paso**
#
# Consideremos el siguiente conjunto de datos, que corresponde a las calificaciones de un grupo de estudiantes:

# %%
import numpy as np
import matplotlib.pyplot as plt

# Conjunto de datos: calificaciones de un grupo de estudiantes
data = [85, 90, 78, 92, 88, 76, 95, 89, 85]

# Calcular la media
media = np.mean(data)

# Cálculo de la varianza (paso a paso)
diferencias_cuadradas = [(x - media)**2 for x in data]  # Calculamos las diferencias al cuadrado
varianza = np.mean(diferencias_cuadradas)

# Cálculo de la desviación estándar
desviacion_estandar = np.sqrt(varianza)

# Cálculo del rango
rango = np.max(data) - np.min(data)

# Mostrar resultados
print(f"Media: {media:.2f}")
print(f"Diferencias cuadradas respecto a la media: {diferencias_cuadradas}")
print(f"Varianza: {varianza:.2f}")
print(f"Desviación Estándar: {desviacion_estandar:.2f}")
print(f"Rango: {rango}")
# Out:
# Media: 86.44
# Diferencias cuadradas respecto a la media: [2.0864197530864153, 12.641975308641987, 71.30864197530862, 30.864197530864214, 2.419753086419758, 109.08641975308639, 73.19753086419756, 6.530864197530872, 2.0864197530864153]
# Varianza: 34.47
# Desviación Estándar: 5.87
# Rango: 19

# %% [markdown]
# ### **Paso a Paso del Cálculo de la Varianza**:
#
# 1. **Media**: Primero calculamos la media del conjunto de datos. Esto nos da el valor central alrededor del cual vamos a medir la dispersión.
#
#   - Ejemplo: La media es \( 86.44 \).
# 2. **Diferencias Cuadradas**: Luego, calculamos la diferencia de cada valor respecto a la media y elevamos esas diferencias al cuadrado para evitar que las desviaciones por encima y por debajo de la media se cancelen.
#
#   - Ejemplo: Las diferencias cuadradas respecto a la media son \( [2.08, 12.67, 72.11, 30.67, 2.44, 109.78, 72.11, 6.78, 2.08] \).
# 3. **Varianza**: Calculamos la **varianza** promediando estas diferencias cuadradas. Esto nos dice cuán dispersos están, en promedio, los datos con respecto a la media.
#
#   - Ejemplo: La varianza es \( 34.19 \), lo que significa que, en promedio, las calificaciones difieren de la media en aproximadamente \( 34.19 \) unidades cuadradas.
# 4. **Desviación Estándar**: Para obtener una medida más fácil de interpretar, calculamos la **desviación estándar** tomando la raíz cuadrada de la varianza, lo que nos devuelve las unidades originales.
#
#   - Ejemplo: La desviación estándar es \( 5.85 \), lo que significa que, en promedio, las calificaciones varían en \( 5.85 \) puntos respecto a la media.
# 5. **Rango**: Finalmente, calculamos el **rango** como la diferencia entre el valor máximo y el valor mínimo.
#
#   - Ejemplo: El rango es \( 19 \), lo que indica que la diferencia entre la calificación

# %% [markdown]
# ### **Visualización Gráfica de las Medidas de Dispersión**
#
# Ahora vamos a visualizar estas medidas de dispersión de manera gráfica, lo cual ayudará a comprender la **intuición** detrás de estos cálculos.
#
# #### **Gráfico 1: Visualización de la Media y las Diferencias Cuadradas**
#
# Primero, graficamos los datos originales y añadimos las diferencias cuadradas respecto

# %%
# Gráfico de las calificaciones con la media y las diferencias cuadradas
plt.figure(figsize=(10,6))

# Graficar los valores originales
plt.scatter(range(1, len(data)+1), data, color='blue', label='Calificaciones', zorder=2)
plt.plot(range(1, len(data)+1), [media] * len(data), color='red', linestyle='dashed', label=f'Media = {media:.2f}', zorder=1)

# Graficar las diferencias cuadradas
for i in range(len(data)):
    plt.plot([i+1, i+1], [data[i], media], color='gray', linestyle='dotted', zorder=0)

plt.title('Diferencias entre las Calificaciones y la Media', fontsize=14)
plt.xlabel('Estudiantes', fontsize=12)
plt.ylabel('Calificaciones', fontsize=12)
plt.legend()
plt.grid(True)
plt.show()

# %% [markdown]
# **Explicación**:
#
# - En este gráfico, las calificaciones individuales están representadas como puntos azules.
# - La línea roja discontinua representa la **media**.
# - Las líneas grises punteadas muestran la diferencia entre cada valor y la media, ilustrando cómo se calculan las diferencias cuadradas para obtener la varianza.
#
# #### **Gráfico 2: Varianza, Desviación Estándar y Rango**
#
# Ahora vamos a visualizar la dispersión de los datos en relación con la **desviación estándar** y el **rango**. Marcamos los límites del rango y mostramos cómo la desviación estándar abarca una parte significativa de los datos.

# %%
# Gráfico de la desviación estándar y el rango
plt.figure(figsize=(10,6))

# Graficar los valores originales
plt.scatter(range(1, len(data)+1), sorted(data), color='blue', label='Calificaciones', zorder=2)

# Graficar la media y la desviación estándar
plt.axhline(y=media, color='red', linestyle='dashed', label=f'Media = {media:.2f}', zorder=1)
plt.axhline(y=media + desviacion_estandar, color='green', linestyle='dashed', label=f'Media + 1 Desv. Est. = {media + desviacion_estandar:.2f}', zorder=1)
plt.axhline(y=media - desviacion_estandar, color='green', linestyle='dashed', label=f'Media - 1 Desv. Est. = {media - desviacion_estandar:.2f}', zorder=1)

# Graficar los límites del rango
plt.axhline(y=np.max(data), color='orange', linestyle='dashed', label=f'Valor Máximo = {np.max(data)}', zorder=0)
plt.axhline(y=np.min(data), color='orange', linestyle='dashed', label=f'Valor Mínimo = {np.min(data)}', zorder=0)

plt.title('Dispersión de las Calificaciones: Desviación Estándar y Rango', fontsize=14)
plt.xlabel('Estudiantes', fontsize=12)
plt.ylabel('Calificaciones', fontsize=12)
plt.legend()
plt.grid(True)
plt.show()

# %% [markdown]
# **Explicación**:
#
# - Este gráfico muestra las calificaciones (puntos azules) junto con la **media** (línea roja) y los límites de la **desviación estándar** (líneas verdes), tanto por encima como por debajo de la media.
# - Las líneas naranjas representan el **rango** (valor máximo y mínimo), lo que nos da una idea visual de la extensión total de los datos.
#
# **Conclusión Visual**:
#
# - La **desviación estándar** mide cuánto varían los datos en relación con la media. En este caso, una desviación estándar abarca una gran parte de los datos.
# - El **rango** nos muestra la diferencia total entre el valor más alto y el más bajo, pero no nos dice nada sobre cómo están distribuidos los valores entre esos extremos, a diferencia de la desviación estándar, que refleja la dispersión general.
#
# ---
#
# ### **Conclusión: Intuición Gráfica de las Medidas de Dispersión**
#
# - La **varianza** y la **desviación estándar** nos proporcionan una medida cuantitativa de cuán alejados están, en promedio, los valores de la media.
# - **Visualmente**, podemos ver cómo las diferencias entre los valores y la media nos ayudan a calcular la varianza, mientras que la desviación estándar nos permite medir la dispersión en unidades más comprensibles.
# - El **rango**, por otro lado, es una medida sencilla pero útil para observar la **extensión total** de los datos, aunque no refleja cómo están distribuidos esos valores.
#
# En conjunto, estas medidas nos permiten tener una **visión completa** tanto de la tendencia central como de la variabilidad de los datos. Las visualizaciones refuerzan esta intuición al mostrar cómo los datos se distribuyen alrededor de la media y cuál es el grado de dispersión en el conjunto de datos.

# %% [markdown]
# # 3. **Cuantiles**
#
# ### **Teoría General**
#
# Los **cuantiles** son valores que dividen un conjunto de datos ordenado en partes iguales, es decir, dividen los datos en diferentes segmentos o intervalos según la frecuencia acumulada. Son herramientas útiles para analizar la **distribución de los datos** y observar cómo se agrupan o se dispersan. Los cuantiles permiten identificar qué porcentaje de los datos se encuentra por debajo o por encima de un valor determinado.
#
# Los tipos más comunes de cuantiles son:
#
# ### 3.1 **Cuartiles**
#
# - **Definición**: Los **cuartiles** dividen un conjunto de datos en **cuatro partes iguales**, de modo que cada parte contenga el **25%** de los datos. Existen tres cuartiles principales que dividen el conjunto:
#
#   - **Q1 (Primer Cuartil)**: El valor que separa el 25% inferior de los datos. Es decir, el **25% de los datos** son menores que este valor.
#   - **Q2 (Segundo Cuartil o Mediana)**: Es la **mediana** del conjunto de datos y separa el 50% inferior del 50% superior.
#   - **Q3 (Tercer Cuartil)**: El valor que separa el 75% inferior del 25% superior. El **75% de los datos** son menores que este valor.
#
#   Matemáticamente, los cuartiles se calculan ordenando los datos y dividiéndolos en cuatro partes:
#
#   - $ Q1 = \text{PERCENTIL}(25) $
#   - $ Q2 = \text{PERCENTIL}(50) = \text{Mediana} $
#   - $ Q3 = \text{PERCENTIL}(75) $
# - **Aplicación**:
#
#   Los cuartiles son útiles para identificar la **distribución de los datos** y entender cómo se agrupan los valores. Son fundamentales en el cálculo de medidas como el **rango intercuartílico**, que mide la dispersión de los datos sin verse afectado por valores extremos. Se aplican comúnmente en estudios de ingresos, análisis de puntuaciones, tiempos de espera, entre otros.
#
# - **Ventajas**:
#
#   - Proporcionan una forma clara de **dividir y analizar** un conjunto de datos.
#   - Son útiles para estudiar la **distribución** sin verse afectados por valores atípicos o extremos.
# - **Limitaciones**:
#
#   - No ofrecen información sobre la dispersión de los datos dentro de cada intervalo, solo delimitan puntos específicos.
#
# ### 3.2 **Percentiles**
#
# - **Definición**: Los **percentiles** dividen un conjunto de datos en **100 partes iguales**, de modo que cada percentil representa el valor por debajo del cual se encuentra un porcentaje específico de los datos. Los percentiles son utilizados con frecuencia para identificar rangos y comparar resultados.
#
#   Por ejemplo:
#
#   - **Percentil 25 (P25)**: El 25% de los datos son menores que este valor.
#   - **Percentil 50 (P50)**: Es la mediana. El 50% de los datos son menores que este valor.
#   - **Percentil 90 (P90)**: El 90% de los datos son menores que este valor.
#
#   Matemáticamente, los percentiles se calculan ordenando los datos y localizando los puntos que dividen los datos en partes iguales:
#
#   $
#   \text{P}k = \text{Percentil} = \frac{k}{100} \cdot (n + 1) \text{, donde } k = \text{porcentaje}
#   $
#
# - **Aplicación**:
#
#   Los percentiles son especialmente útiles para **comparaciones relativas** en distribuciones, como en exámenes o mediciones de rendimiento, donde se busca comparar cómo se desempeña un individuo en relación con un grupo más amplio. Son ampliamente utilizados en estadísticas de salud, como los percentiles de crecimiento infantil o en pruebas estandarizadas.
#
# - **Ventajas**:
#
#   - Proporcionan una herramienta precisa para **comparar posiciones** dentro de una distribución.
#   - Son aplicables en diversos campos, desde la educación hasta la salud pública.
# - **Limitaciones**:
#
#   - Pueden ser **sensibles a valores extremos** si no se analiza su impacto en los percentiles.
#
# ---
#
# ### **Cálculo de Cuantiles Paso a Paso**
#
# Ahora calcularemos y analizaremos los cuartiles y percentiles en Python, utilizando el mismo conjunto de datos de calificaciones de estudiantes que hemos empleado en las secciones anteriores:

# %%
import numpy as np

# Conjunto de datos: calificaciones de un grupo de estudiantes
data = [85, 90, 78, 92, 88, 76, 95, 89, 85]

# Calcular los cuartiles
Q1 = np.percentile(data, 25)
Q2 = np.percentile(data, 50)  # También conocido como la mediana
Q3 = np.percentile(data, 75)

# Calcular percentiles específicos
P90 = np.percentile(data, 90)

# Mostrar resultados
print(f"Q1 (Cuartil 1) = {Q1}")
print(f"Q2 (Mediana) = {Q2}")
print(f"Q3 (Cuartil 3) = {Q3}")
print(f"Percentil 90 = {P90}")
# Out:
# Q1 (Cuartil 1) = 85.0
# Q2 (Mediana) = 88.0
# Q3 (Cuartil 3) = 90.0
# Percentil 90 = 92.6

# %% [markdown]
# Paso a Paso del Cálculo de Cuantiles**:
#
# 1. **Cuartiles**:
#
#   - **Q1**: Representa el valor por debajo del cual se encuentra el 25% de los datos.
#   - **Q2 (Mediana)**: Representa el valor por debajo del cual se encuentra el 50% de los datos.
#   - **Q3**: Representa el valor por debajo del cual se encuentra el 75% de los datos.
#
#   En nuestro ejemplo, podríamos obtener que:
#
#   - $ Q1 = 85 $
#   - $ Q2 = 88 $ (la mediana)
#   - $ Q3 = 90 $
# 2. **Percentiles**:
#
#   - Por ejemplo, el **Percentil 90 (P90)** representa el valor por debajo del cual se encuentra el 90% de los datos.
#
#   En nuestro ejemplo, $ P90 = 92.6 $, lo que significa que el 90% de los estudiantes obtuvo una calificación menor o igual a 92.8.
#
#
# ---
#
# ### **Visualización Gráfica de los Cuantiles**
#
# Para visualizar mejor cómo los cuartiles y percentiles dividen los datos, vamos a graficarlos:
#
# #### **Gráfico de Cuartiles y Percentiles**

# %%
# Gráfico de los cuartiles y percentiles
plt.figure(figsize=(10,6))

# Graficar los datos originales
plt.scatter(range(1, len(data)+1), sorted(data), color='blue', label='Calificaciones')

# Graficar los cuartiles
plt.axhline(Q1, color='green', linestyle='dashed', label=f'Q1 (25%) = {Q1}')
plt.axhline(Q2, color='red', linestyle='dashed', label=f'Q2 (50% - Mediana) = {Q2}')
plt.axhline(Q3, color='blue', linestyle='dashed', label=f'Q3 (75%) = {Q3}')

# Graficar el percentil 90
plt.axhline(P90, color='purple', linestyle='dashed', label=f'P90 (90%) = {P90}')

plt.title('Distribución de Cuartiles y Percentiles en las Calificaciones', fontsize=14)
plt.xlabel('Estudiantes Ordenados', fontsize=12)
plt.ylabel('Calificaciones', fontsize=12)
plt.legend()
plt.grid(True)
plt.show()

# %% [markdown]
# **Interpretación Gráfica**:
#
# - En este gráfico, los puntos azules representan las **calificaciones** ordenadas de menor a mayor.
# - Las líneas punteadas representan los **cuartiles (Q1, Q2, Q3)**, que dividen los datos en partes iguales. La línea roja, que corresponde a la mediana, divide el conjunto de datos en dos mitades.
# - La línea morada marca el **percentil 90 (P90)**, que muestra el valor por debajo del cual se encuentra el 90% de los datos.
#
# Este gráfico ayuda a **visualizar cómo los datos se distribuyen** y cómo los cuartiles y percentiles proporcionan información sobre la dispersión de los valores. En este caso, observamos que el 25% de las calificaciones son iguales o inferiores a 85, el 50% son iguales o inferiores a 88, y el 90% son iguales o inferiores a 92.6.
#
# ---
# El valor del percentil 90 no toma un valor exacto de los datos porque es una estimación basada en la posición que ocupa dentro del conjunto ordenado de datos. En estadística, cuando calculamos percentiles (incluido el percentil 90), frecuentemente no coinciden exactamente con los valores específicos de los datos debido a la interpolación, especialmente cuando el percentil cae entre dos puntos de datos.
#
# El percentil 90 indica el valor por debajo del cual el 90% de los datos se encuentran. Si este percentil no cae exactamente en un valor observado de los datos, se utiliza un método de interpolación para estimar el valor. Este es el motivo por el cual el percentil 90 puede aparecer como un número que no es un valor exacto de los datos.
#
# Para entender mejor esto, veamos cómo se calcula típicamente un percentil cuando no coincide con un dato exacto:
#
# 1. **Ordenar los Datos**: Primero, los datos se ordenan en forma ascendente.
# 2. **Calcular la posición del percentil**: La posición del percentil $ p $ en un conjunto de datos con $ n $ elementos se calcula como:
#    $
#    \text{Posición} = \frac{p}{100} \times (n + 1)
#    $
# 3. **Interpolación**: Si la posición calculada no es un número entero, se interpola entre los dos valores más cercanos.
#
# Por ejemplo, si calculamos el percentil 90 para un conjunto de datos de 9 elementos:
#
# - La posición teórica sería $ \frac{90}{100} \times (9 + 1) = 9.0 $, indicando el noveno valor.
# - Si la posición fuese 8.5, esto implicaría que el percentil 90 está justo entre el octavo y el noveno valor de los datos ordenados.
#
# Dado que en el gráfico proporcionado el percentil 90 es 92.6, este valor es una interpolación entre el noveno y décimo valor en el conjunto de datos ordenado (si hubiera un décimo valor). Si no hay un décimo valor, la interpolación puede depender de métodos específicos que pueden extender el rango de los datos existentes para estimar este percentil, o simplemente utilizar el valor más cercano que en este caso es el noveno valor.
#
# Este método garantiza que los percentiles representen precisamente la distribución acumulativa de los datos, aún cuando no coincidan exactamente con los valores observados, lo cual es una práctica común en estadística para proporcionar una descripción detallada y precisa de la distribución de datos.
#
# ---
#
# ### **Conclusión: Intuición Detrás de los Cuantiles**
#
# Los **cuantiles**, incluyendo los **cuartiles** y **percentiles**, son una forma poderosa de **dividir y analizar** conjuntos de datos. Nos proporcionan información sobre cómo se distribuyen los valores, dividiendo los datos en segmentos manejables para su análisis. Los cuartiles nos permiten ver claramente cómo se agrupan los datos en 25%, 50% y 75%,
#
# mientras que los percentiles nos dan una visión aún más detallada para comparar valores individuales dentro de una distribución.
#
# Las visualizaciones ayudan a desarrollar la **intuición** detrás de estos conceptos, mostrando cómo los cuantiles dividen los datos y facilitando la comprensión de la **distribución de los valores** en cualquier contexto de análisis.

# %% [markdown]
# # 4. **Gráficas de Puntos (Dot Plots)**
#
# ### **Teoría General**
#
# Las **gráficas de puntos** o **dot plots** son un tipo de visualización en la que **cada valor individual** en un conjunto de datos es representado como un punto a lo largo de una escala numérica. Es una manera sencilla y directa de visualizar **distribuciones de datos discretos o continuos**, permitiendo observar claramente la **frecuencia** y **dispersión** de los datos.
#
# - **Estructura**: En una gráfica de puntos, los valores se representan en una línea numérica, y los puntos se apilan verticalmente si hay valores repetidos. Esto ayuda a visualizar tanto la **frecuencia** como la **distribución** de los datos en un conjunto.
#
#   Las gráficas de puntos son útiles cuando:
#
#   - El tamaño del conjunto de datos es pequeño o mediano.
#   - Se busca comparar distribuciones entre diferentes grupos.
#   - Se desea ver cómo los datos están **agrupados** o **dispersos** en una escala.
# - **Ventajas**:
#
#   - Permiten observar cada punto de datos individualmente, lo que ofrece una visión clara de la distribución sin necesidad de agregación.
#   - Son ideales para identificar patrones, agrupaciones o valores atípicos en conjuntos de datos pequeños o medianos.
# - **Limitaciones**:
#
#   - No son tan efectivas para conjuntos de datos muy grandes, ya que pueden volverse difíciles de interpretar cuando hay demasiados puntos.
#
# ### **Aplicaciones Comunes**:
#
# Las gráficas de puntos se utilizan ampliamente en:
#
# - **Educación**: Para representar calificaciones o resultados de pruebas.
# - **Estadísticas descriptivas**: Para mostrar la distribución de variables numéricas.
# - **Comparación de grupos**: Comparar las distribuciones entre diferentes categorías.
#
# ---
#
# ### **Cálculo y Creación de una Gráfica de Puntos**
#
# Vamos a crear una gráfica de puntos utilizando el mismo conjunto de datos de calificaciones que hemos usado antes:

# %%
import numpy as np
import matplotlib.pyplot as plt

# Conjunto de datos: calificaciones de un grupo de estudiantes
data = [85, 90, 92, 88, 76, 95, 89, 85,85, 78, 81, 83, 83]

# Contar la frecuencia de cada valor
values, counts = np.unique(data, return_counts=True)

# Ajustar el tamaño de la figura y la visualización
fig, ax = plt.subplots(figsize=(6, 2.5))

# Dibujar la gráfica de puntos apilados con el formato adecuado
for value, count in zip(values, counts):
    ax.plot([value] * count, list(range(count)), 'bo', ms=10, linestyle='')

# Configuraciones de formato del gráfico
for spine in ['top', 'right', 'left']:
    ax.spines[spine].set_visible(False)

ax.yaxis.set_visible(False)
ax.set_ylim(-1, max(counts))
ax.set_xticks(range(min(values), max(values)+1))

# Ajustar el tamaño de las etiquetas del eje X
ax.tick_params(axis='x', length=0, pad=8, labelsize=8)  # Ajustamos el tamaño a 8

# Título y etiquetas
ax.set_xlabel('Calificaciones', fontsize=10)
ax.set_title('Gráfica de Puntos (Dot Plot) Apilados', fontsize=12)

plt.show()

# %% [markdown]
# Las **gráficas de puntos** ofrecen una manera simple y directa de visualizar datos individuales en una escala numérica. Son especialmente útiles para conjuntos de datos pequeños o medianos, ya que permiten observar cada valor individualmente, mostrando la **frecuencia** y la **distribución** sin necesidad de agrupar los datos.
#
# Con este tipo de visualización, es fácil identificar patrones, valores atípicos o diferencias entre grupos. Si bien tienen algunas limitaciones para conjuntos de datos muy grandes, las gráficas de puntos son una excelente herramienta cuando se busca claridad y simplicidad en la visualización de datos numéricos.

# %% [markdown]
# # 5. **Resumen de Información**
#
# El resumen de información nos permite obtener una visión clara y estructurada de cómo están distribuidos los datos. Las herramientas más comunes para realizar un análisis de datos incluyen **tablas de frecuencias**, **histogramas**, **ojivas** y el cálculo de **indicadores de forma** como la **asimetría** y la **curtosis**. A continuación, exploraremos cada uno de estos elementos.
#
# ---
#
# ### 5.1 **Tablas de Frecuencias: Definición y Elaboración Paso a Paso**
#
# #### **Teoría**
#
# Una **tabla de frecuencias** es una herramienta utilizada en estadísticas descriptivas que organiza un conjunto de datos en clases o intervalos, contando la **frecuencia absoluta** (el número de veces que ocurre un valor o grupo de valores) y calculando la **frecuencia relativa** (la proporción de veces que ocurre un valor o grupo de valores con respecto al total de datos). Esta tabla puede incluir también la **frecuencia acumulada**, que es la suma de las frecuencias absolutas hasta un cierto punto.
#
# La construcción de una tabla de frecuencias consta de los siguientes pasos:
#
# 1. **Determinar el rango o amplitud de los datos**: Se calcula la diferencia entre el valor máximo y el valor mínimo del conjunto de datos.
# 2. **Determinar el número de clases**: Utilizando métodos como la raíz cuadrada de \(n\) o la fórmula de Sturges, se decide cuántas clases o intervalos se usarán.
# 3. **Calcular el tamaño de las clases**: Se divide la amplitud de los datos entre el número de clases para obtener el tamaño de cada clase.
# 4. **Definir los límites de las clases**: Se determina el rango de cada clase, empezando por el valor mínimo y sumando el tamaño de clase hasta el valor máximo.
# 5. **Contar la frecuencia en cada clase**: Se cuenta cuántos datos caen dentro de cada clase.
# 6. **Calcular la frecuencia relativa**: Se calcula dividiendo la frecuencia absoluta entre el total de datos.
# 7. **Calcular la frecuencia acumulada**: Se obtiene sumando las frecuencias absolutas hasta cada clase.
#
# ---
#
# ### **Ejemplo en Python: Tabla de Frecuencias Paso a Paso**
#
# Utilizaremos un conjunto de calificaciones de estudiantes para ilustrar cómo construir una tabla de frecuencias de manera automatizada.
#
# #### **Paso 1: Determinar la amplitud de los datos**
#
# La **amplitud de variación** es la diferencia entre el valor máximo y el valor mínimo en el conjunto de datos.

# %%
import numpy as np

# Conjunto de datos: calificaciones de un grupo de estudiantes
data = [85, 90, 78, 92, 88, 76, 95, 89, 85, 90, 91, 84, 93, 87, 77, 96, 85, 90, 88, 86,
        92, 81, 89, 93, 90, 79, 85, 87, 92, 94, 83, 88, 86, 95, 91, 80, 84, 82, 94, 89,
        88, 90, 92, 85, 96, 87, 85, 93, 91, 89]

# Calcular el valor mínimo, máximo y la amplitud de variación
minimo = min(data)
maximo = max(data)
amplitud_variacion = maximo - minimo

print(f"Valor mínimo: {minimo}, Valor máximo: {maximo}, Amplitud de variación: {amplitud_variacion}")
# Out:
# Valor mínimo: 76, Valor máximo: 96, Amplitud de variación: 20

# %% [markdown]
# **Paso 2: Determinar el número de clases**
#
# El **número de clases** es el número de intervalos en los que queremos dividir nuestros datos para organizar la tabla. Existen varios métodos para determinar este número, pero uno de los más comunes es la **fórmula de Sturges**:
#
# ### **Fórmula de Sturges**:
#
# $
# C = 1 + 3.322 \cdot \log_{10}(n)
# $
#
# Donde:
#
# - $C$ es el número de clases.
# - $n$ es el número total de observaciones.
#
# Esta fórmula toma en cuenta el tamaño del conjunto de datos para ajustar el número de clases. **Intuitivamente**, la fórmula de Sturges busca un equilibrio entre tener demasiadas clases (lo que podría hacer difícil interpretar los datos) y tener muy pocas clases (lo que podría ocultar detalles importantes de la distribución de los datos).
#
# #### **Ejemplo en Python**:

# %%
import math

# Número total de datos
n = len(data)

# Fórmula de Sturges para determinar el número de clases
clases_sturges = round(1 + 3.322 * math.log10(n))
print(f"Número de clases (Sturges): {clases_sturges}")
# Out:
# Número de clases (Sturges): 7

# %% [markdown]
# La **fórmula de Sturges** ha determinado que para este conjunto de datos de 50 observaciones, el número ideal de clases es **7**.
#
# #### **Sentido Intuitivo de la Fórmula de Sturges**:
#
# - Si tenemos pocos datos (\(n\) pequeño), la fórmula tenderá a dar un número pequeño de clases, lo que tiene sentido porque no queremos sobrecargar los datos con demasiados intervalos.
# - Si tenemos muchos datos (\(n\) grande), la fórmula sugiere más clases, permitiéndonos captar más detalles de la distribución de los datos sin perder claridad.
#
# ---

# %% [markdown]
# **Paso 3: Calcular el tamaño de las clases**
#
# El **tamaño de cada clase** se calcula dividiendo la **amplitud de variación** entre el número de clases.
#
# #### **Fórmula**:
#
# $
# \text{Tamaño de Clase} = \frac{\text{Amplitud de Variación}}{\text{Número de Clases}}
# $
#
# #### **Ejemplo en Python**:

# %%
# Calcular el tamaño de clase
tamano_clase = round(amplitud_variacion / clases_sturges, 2)
print(f"Tamaño de cada clase: {tamano_clase}")
# Out:
# Tamaño de cada clase: 2.86

# %% [markdown]
# Esto significa que cada clase abarcará un rango de **2.86 unidades** (por ejemplo, de 76.00 a 78.86, de 78.86 a 81.71, etc.).

# %% [markdown]
# #### **Paso 4: Definir los límites de las clases**
#
# Usando el tamaño de clase calculado, podemos definir los **límites inferiores** y **superiores** de cada clase. La primera clase empieza en el valor mínimo, y las siguientes clases se definen sumando el tamaño de clase de forma sucesiva.
#
# #### **Ejemplo en Python**:

# %%
# Definir los límites inferiores y superiores de las clases
limites_inferiores = np.arange(minimo, maximo, tamano_clase)
limites_superiores = limites_inferiores + tamano_clase

# Mostrar los límites de clase
for i in range(len(limites_inferiores)):
    print(f"Clase {i+1}: {limites_inferiores[i]:.2f} - {limites_superiores[i]:.2f}")
# Out:
# Clase 1: 76.00 - 78.86
# Clase 2: 78.86 - 81.72
# Clase 3: 81.72 - 84.58
# Clase 4: 84.58 - 87.44
# Clase 5: 87.44 - 90.30
# Clase 6: 90.30 - 93.16
# Clase 7: 93.16 - 96.02

# %% [markdown]
# #### **Paso 5: Contar la frecuencia en cada clase**
#
# Utilizando estos intervalos de clase, contamos cuántos datos caen dentro de cada clase para obtener la **frecuencia absoluta**.
#
# #### **Ejemplo en Python**:

# %%
# Crear la tabla de frecuencias
frecuencias_absolutas, _ = np.histogram(data, bins=np.arange(minimo, maximo+tamano_clase, tamano_clase))

# Mostrar frecuencias absolutas
for i in range(len(frecuencias_absolutas)):
    print(f"Clase {i+1}: {limites_inferiores[i]:.2f} - {limites_superiores[i]:.2f}, Frecuencia absoluta: {frecuencias_absolutas[i]}")
# Out:
# Clase 1: 76.00 - 78.86, Frecuencia absoluta: 3
# Clase 2: 78.86 - 81.72, Frecuencia absoluta: 3
# Clase 3: 81.72 - 84.58, Frecuencia absoluta: 4
# Clase 4: 84.58 - 87.44, Frecuencia absoluta: 11
# Clase 5: 87.44 - 90.30, Frecuencia absoluta: 13
# Clase 6: 90.30 - 93.16, Frecuencia absoluta: 10
# Clase 7: 93.16 - 96.02, Frecuencia absoluta: 6

# %% [markdown]
# #### **Paso 6: Calcular la frecuencia relativa**
#
# La **frecuencia relativa** es la proporción de datos en cada clase con respecto al total de datos. Se calcula dividiendo la frecuencia absoluta entre el número total de datos.
#
# #### **Fórmula**:
#
# $
# \text{Frecuencia Relativa} = \frac{\text{Frecuencia Absoluta}}{n}
# $
#
# #### **Ejemplo en Python**:

# %%
# Calcular la frecuencia relativa
frecuencia_relativa = frecuencias_absolutas / n

# Mostrar frecuencia relativa
for i in range(len(frecuencia_relativa)):
    print(f"Clase {i+1}: {limites_inferiores[i]:.2f} - {limites_superiores[i]:.2f}, Frecuencia relativa: {frecuencia_relativa[i]:.2f}")
# Out:
# Clase 1: 76.00 - 78.86, Frecuencia relativa: 0.06
# Clase 2: 78.86 - 81.72, Frecuencia relativa: 0.06
# Clase 3: 81.72 - 84.58, Frecuencia relativa: 0.08
# Clase 4: 84.58 - 87.44, Frecuencia relativa: 0.22
# Clase 5: 87.44 - 90.30, Frecuencia relativa: 0.26
# Clase 6: 90.30 - 93.16, Frecuencia relativa: 0.20
# Clase 7: 93.16 - 96.02, Frecuencia relativa: 0.12

# %% [markdown]
# #### **Paso 7: Calcular la frecuencia acumulada**
#
# La **frecuencia acumulada** es la suma de las frecuencias absolutas hasta un determinado punto, y muestra cuántos datos caen por debajo de ciertos límites de clase.
#
# #### **Ejemplo en Python**:

# %%
# Calcular la frecuencia acumulada
frecuencia_acumulada = np.cumsum(frecuencias_absolutas)

# Mostrar frecuencia acumulada
for i in range(len(frecuencia_acumulada)):
    print(f"Clase {i+1}: {limites_inferiores[i]:.2f} - {limites_superiores[i]:.2f}, Frecuencia acumulada: {frecuencia_acumulada[i]}")
# Out:
# Clase 1: 76.00 - 78.86, Frecuencia acumulada: 3
# Clase 2: 78.86 - 81.72, Frecuencia acumulada: 6
# Clase 3: 81.72 - 84.58, Frecuencia acumulada: 10
# Clase 4: 84.58 - 87.44, Frecuencia acumulada: 21
# Clase 5: 87.44 - 90.30, Frecuencia acumulada: 34
# Clase 6: 90.30 - 93.16, Frecuencia acumulada: 44
# Clase 7: 93.16 - 96.02, Frecuencia acumulada: 50

# %% [markdown]
# ### **Tabla de Frecuencias Final**
#
# Podemos organizar todo en una tabla para visualizar mejor los resultados:

# %%
import pandas as pd

# Crear un DataFrame para organizar la tabla de frecuencias
tabla_frecuencias = pd.DataFrame({
    'Clase': [f"{limites_inferiores[i]:.2f} - {limites_superiores[i]:.2f}" for i in range(len(limites_inferiores))],
    'Frecuencia Absoluta': frecuencias_absolutas,
    'Frecuencia Relativa': frecuencia_relativa,
    'Frecuencia Acumulada': frecuencia_acumulada
})

# Mostrar la tabla de frecuencias
tabla_frecuencias
# Out:
#            Clase  Frecuencia Absoluta  Frecuencia Relativa  \
# 0  76.00 - 78.86                    3                 0.06
# 1  78.86 - 81.72                    3                 0.06
# 2  81.72 - 84.58                    4                 0.08
# 3  84.58 - 87.44                   11                 0.22
# 4  87.44 - 90.30                   13                 0.26
# 5  90.30 - 93.16                   10                 0.20
# 6  93.16 - 96.02                    6                 0.12
#
#    Frecuencia Acumulada
# 0                     3
# 1                     6
# 2                    10
# 3                    21
# 4                    34
# 5                    44
# 6                    50

# %% [markdown]
# Este proceso automatizado en Python nos permite construir una **tabla de frecuencias** paso a paso, utilizando la **fórmula de Sturges** para determinar el número de clases. La tabla de frecuencias final nos ofrece una descripción clara y completa de cómo están distribuidos los datos, facilitando el análisis de **distribuciones** y el cálculo de **medidas de tendencia central** o **dispersión**.

# %% [markdown]
# 5.2 **Histograma**
#
# #### **Teoría**:
#
# Un **histograma** es un tipo de gráfico de barras utilizado para representar la **distribución de frecuencias** de un conjunto de datos. Los datos se agrupan en **clases** o **intervalos** (que pueden ser determinados mediante métodos como la **fórmula de Sturges**), y la altura de cada barra representa la **frecuencia absoluta** o **frecuencia relativa** de los datos dentro de ese intervalo.
#
# ### **Características principales de un histograma**:
#
# - **Clases o intervalos**: Los datos se agrupan en intervalos contiguos, de igual tamaño, para facilitar la visualización de la distribución.
# - **Altura de las barras**: La altura de cada barra es proporcional al número de datos (frecuencia) que caen dentro del intervalo correspondiente.
# - **Contigüidad**: A diferencia de un gráfico de barras, en un histograma las barras están **contiguas** entre sí, lo que refleja que los datos están organizados en intervalos continuos.
# - **Datos continuos**: Los histogramas son especialmente útiles para datos **continuos**, como temperaturas, tiempos o calificaciones, donde los valores pueden tomar cualquier valor dentro de un rango.
#
# ---
#
# ### **Pasos para construir un histograma**
#
# 1. **Determinar las clases o intervalos**: Como hicimos en el proceso de la **tabla de frecuencias**, determinamos el número de clases utilizando la **fórmula de Sturges** o dividiendo el rango de los datos en intervalos de igual tamaño.
# 2. **Contar la frecuencia en cada clase**: Una vez definidos los intervalos, contamos cuántos datos caen dentro de cada clase o intervalo.
# 3. **Graficar el histograma**: Se representa el **intervalo** en el eje X y la **frecuencia** (o frecuencia relativa) en el eje Y.
#
# ---
#
# ### **Ejemplo en Python: Construcción de un histograma**
#
# Vamos a utilizar el mismo conjunto de datos de calificaciones de estudiantes que hemos usado anteriormente. Primero, determinaremos las clases utilizando la **fórmula de Sturges** y luego graficaremos el histograma.
#
# #### **Paso 1: Determinar las clases y frecuencias**
#
# Para determinar los intervalos o clases, utilizaremos los pasos que seguimos en la **tabla de frecuencias** (determinación de clases por Sturges, cálculo del tamaño de clase, y conteo de frecuencias).

# %%
import numpy as np
import matplotlib.pyplot as plt
import math

# Conjunto de datos: calificaciones de un grupo de estudiantes
data = [85, 90, 78, 92, 88, 76, 95, 89, 85, 90, 91, 84, 93, 87, 77, 96, 85, 90, 88, 86,
        92, 81, 89, 93, 90, 79, 85, 87, 92, 94, 83, 88, 86, 95, 91, 80, 84, 82, 94, 89,
        88, 90, 92, 85, 96, 87, 85, 93, 91, 89]

# Determinamos el valor mínimo, máximo y la amplitud de variación
minimo = min(data)
maximo = max(data)
amplitud_variacion = maximo - minimo

# Número total de datos
n = len(data)

# Fórmula de Sturges para determinar el número de clases
clases_sturges = round(1 + 3.322 * math.log10(n))

# Calcular el tamaño de clase
tamano_clase = round(amplitud_variacion / clases_sturges, 2)

# Mostrar el número de clases y el tamaño de clase
print(f"Número de clases (Sturges): {clases_sturges}")
print(f"Tamaño de clase: {tamano_clase}")
# Out:
# Número de clases (Sturges): 7
# Tamaño de clase: 2.86

# %% [markdown]
# #### **Paso 2: Graficar el histograma**
#
# Ahora que conocemos el número de clases y el tamaño de cada clase, utilizamos la función `plt.hist()` de `matplotlib` para crear el histograma. El número de **bins** será el número de clases, y la **frecuencia** de cada clase será calculada automáticamente.

# %%
# Graficar el histograma
plt.hist(data, bins=clases_sturges, edgecolor='black', color='skyblue')

# Añadir título y etiquetas
plt.title('Histograma de Calificaciones', fontsize=14)
plt.xlabel('Calificaciones', fontsize=12)
plt.ylabel('Frecuencia', fontsize=12)

# Mostrar el gráfico
plt.grid(True)
plt.show()

# %% [markdown]
# **Resultado del gráfico**:
#
# Este código genera un histograma con **7 barras**, donde cada barra representa un intervalo de calificaciones (definido por el tamaño de clase de 2.86 unidades), y la altura de cada barra muestra la **frecuencia** de las calificaciones que caen dentro de ese intervalo.
#
# ### **Interpretación del Histograma**:
#
# - El **eje X** muestra los intervalos de calificaciones (por ejemplo, de **76.00 a 78.86**, de **78.86 a 81.71**, etc.).
# - El **eje Y** muestra la **frecuencia absoluta**, es decir, cuántas calificaciones caen en cada intervalo.
# - El histograma nos permite observar la **distribución** de las calificaciones:
#   - Si las barras más altas están a la izquierda, la distribución podría estar sesgada hacia valores más bajos.
#   - Si las barras más altas están en el centro, la distribución podría ser más simétrica, con valores concentrados alrededor de la media.
#
# ---
#
# ### **Paso 3: Añadir la frecuencia relativa (opcional)**
#
# Si queremos que el histograma muestre la **frecuencia relativa** en lugar de la frecuencia absoluta, podemos agregar el argumento `density=True` en la función `plt.hist()`. Esto normaliza las barras de modo que el área total del histograma sea igual a 1.

# %%
# Graficar el histograma con frecuencias relativas
plt.hist(data, bins=clases_sturges, edgecolor='black', color='skyblue', density=True)

# Añadir título y etiquetas
plt.title('Histograma de Calificaciones (Frecuencia Relativa)', fontsize=14)
plt.xlabel('Calificaciones', fontsize=12)
plt.ylabel('Frecuencia Relativa', fontsize=12)

# Mostrar el gráfico
plt.grid(True)
plt.show()

# %% [markdown]
# Interpretación**:
#
# - Ahora, el eje Y muestra la **frecuencia relativa**, es decir, la proporción de datos que caen en cada intervalo con respecto al total.
# - La **suma del área de todas las barras** es igual a **1**, lo que significa que estamos trabajando con proporciones.
#
# ---
#
# ### **Conclusión**
#
# El **histograma** es una herramienta visual poderosa que nos permite observar la **distribución de los datos** de manera rápida y efectiva. Gracias a su estructura, es ideal para trabajar con datos **continuos** o cuando se necesita visualizar datos agrupados en intervalos.
#
# - **Ventajas**:
#
#   - Nos permite identificar la **forma de la distribución**: si es **simétrica**, **sesgada** a la derecha o izquierda, o si tiene múltiples picos.
#   - Es útil para detectar **valores atípicos** o **outliers**.
#   - Facilita la visualización de grandes conjuntos de datos al agruparlos en intervalos.
# - **Limitaciones**:
#
#   - La elección del número de clases o intervalos puede afectar la interpretación del histograma. Si hay muy pocas clases, podemos perder detalle, y si hay demasiadas, el gráfico puede volverse ruidoso.
#   - Para datos **discretos** (como conteos de enteros), puede no ser tan útil como otras visualizaciones (como gráficos de barras o gráficos de puntos).
#
# El histograma es una herramienta fundamental en el análisis de datos, ya que proporciona una visión clara de cómo los datos están distribuidos y facilita la comprensión de su comportamiento.

# %% [markdown]
# ### 5.3 **Ojiva**
#
# #### **Teoría**:
#
# La **ojiva** es un tipo de gráfico que muestra la **frecuencia acumulada** de un conjunto de datos. Representa cómo se acumulan los datos conforme avanzamos por los valores, permitiendo visualizar el número total de observaciones por debajo de un cierto valor.
#
# A diferencia de un **histograma**, que muestra la distribución de los datos en intervalos, la ojiva se utiliza para observar cómo se **acumulan** los datos a medida que recorremos el rango de valores. Esto es especialmente útil para calcular **percentiles** y analizar cómo se distribuyen los datos en diferentes partes del conjunto.
#
# ### **Características principales de la Ojiva**:
#
# - La ojiva es un gráfico de **línea** que muestra la **frecuencia acumulada** en el eje Y y los **valores de los datos** en el eje X.
# - Es útil para analizar la **distribución acumulativa** de los datos y para encontrar valores como el **percentil 50** (mediana), el **percentil 25** o el **percentil 90**.
# - Nos permite responder preguntas como: "¿Cuántos datos son menores que un valor determinado?" o "¿En qué rango se encuentran los primeros 50% de los datos?".
#
# ---
#
# ### **Pasos para construir una Ojiva**
#
# 1. **Determinar las clases** o **intervalos** en los que se agruparán los datos (igual que en la tabla de frecuencias).
# 2. **Calcular la frecuencia acumulada** de los datos en cada intervalo.
# 3. **Graficar la ojiva**, colocando los puntos de cada intervalo y su correspondiente frecuencia acumulada en el gráfico.
#
# ---
#
# ### **Ejemplo en Python: Construcción de una Ojiva**
#
# Para construir la ojiva, utilizaremos el mismo conjunto de **calificaciones de estudiantes** que hemos venido usando, y seguiremos el mismo proceso para calcular las clases y frecuencias, pero ahora nos enfocaremos en la **frecuencia acumulada**.
#
# #### **Paso 1: Determinar las clases y la frecuencia acumulada**
#
# Utilizaremos la fórmula de Sturges para determinar las clases y luego calcularemos la frecuencia acumulada.

# %%
import numpy as np
import matplotlib.pyplot as plt
import math

# Conjunto de datos: calificaciones de un grupo de estudiantes
data = [85, 90, 78, 92, 88, 76, 95, 89, 85, 90, 91, 84, 93, 87, 77, 96, 85, 90, 88, 86,
        92, 81, 89, 93, 90, 79, 85, 87, 92, 94, 83, 88, 86, 95, 91, 80, 84, 82, 94, 89,
        88, 90, 92, 85, 96, 87, 85, 93, 91, 89]

# Determinar el valor mínimo, máximo y la amplitud de variación
minimo = min(data)
maximo = max(data)
amplitud_variacion = maximo - minimo

# Número total de datos
n = len(data)

# Fórmula de Sturges para determinar el número de clases
clases_sturges = round(1 + 3.322 * math.log10(n))

# Calcular el tamaño de clase
tamano_clase = round(amplitud_variacion / clases_sturges, 2)

# Crear los intervalos de clase
limites_inferiores = np.arange(minimo, maximo, tamano_clase)
limites_superiores = limites_inferiores + tamano_clase

# Crear la tabla de frecuencias
frecuencias_absolutas, _ = np.histogram(data, bins=np.arange(minimo, maximo+tamano_clase, tamano_clase))

# Calcular la frecuencia acumulada
frecuencia_acumulada = np.cumsum(frecuencias_absolutas)

# Mostrar las clases y la frecuencia acumulada
for i in range(len(frecuencia_acumulada)):
    print(f"Clase {i+1}: {limites_inferiores[i]:.2f} - {limites_superiores[i]:.2f}, Frecuencia acumulada: {frecuencia_acumulada[i]}")
# Out:
# Clase 1: 76.00 - 78.86, Frecuencia acumulada: 3
# Clase 2: 78.86 - 81.72, Frecuencia acumulada: 6
# Clase 3: 81.72 - 84.58, Frecuencia acumulada: 10
# Clase 4: 84.58 - 87.44, Frecuencia acumulada: 21
# Clase 5: 87.44 - 90.30, Frecuencia acumulada: 34
# Clase 6: 90.30 - 93.16, Frecuencia acumulada: 44
# Clase 7: 93.16 - 96.02, Frecuencia acumulada: 50

# %% [markdown]
# En este resultado, vemos cómo la **frecuencia acumulada** nos muestra cuántos datos se han contado hasta cada clase. Por ejemplo, **3** estudiantes tienen una calificación entre **76.00 y 78.86**, y un total de **50** estudiantes han sido contabilizados hasta el intervalo más alto.
#
# ---
#
# #### **Paso 2: Graficar la Ojiva**
#
# Para graficar la ojiva, simplemente colocamos en el eje **X** los límites superiores de las clases y en el eje **Y** la **frecuencia acumulada** correspondiente.

# %%
# Graficar la Ojiva (Frecuencia Acumulada)
plt.plot(limites_superiores, frecuencia_acumulada, marker='o', linestyle='-', color='blue')

# Añadir título y etiquetas
plt.title('Ojiva de Frecuencia Acumulada', fontsize=14)
plt.xlabel('Calificaciones', fontsize=12)
plt.ylabel('Frecuencia Acumulada', fontsize=12)

# Mostrar la cuadrícula y el gráfico
plt.grid(True)
plt.show()

# %% [markdown]
# Interpretación del gráfico**:
#
# - La **ojiva** comienza en el primer valor de la clase inferior y continúa hacia la derecha, mostrando cómo se acumulan las frecuencias a medida que se avanzan por los intervalos de datos.
# - El eje **X** representa las **calificaciones**, y el eje **Y** muestra cuántos estudiantes tienen calificaciones menores o iguales al valor de la clase superior en el eje X.
# - Este gráfico es útil para identificar valores como el **percentil 50** (la mediana), que corresponde al valor en el que la frecuencia acumulada alcanza el 50% del total.
#
# ---
#
# ### **Paso 3: Identificar Percentiles en la Ojiva (Opcional)**
#
# Una de las grandes ventajas de la ojiva es que nos permite **calcular percentiles**, como el **percentil 25**, el **percentil 50** (mediana) o el **percentil 75**.
#
# Por ejemplo, el **percentil 50** es el punto donde la frecuencia acumulada es igual al 50% del total de datos.
#
# #### **Cálculo del Percentil 50 (Mediana)**:

# %%
# Calcular la mediana (percentil 50)
mediana = np.percentile(data, 50)
print(f"Mediana (Percentil 50): {mediana}")
# Out:
# Mediana (Percentil 50): 88.5

# %% [markdown]
# La **ojiva** es una herramienta visual importante para **analizar la acumulación de datos** y observar cómo se distribuyen a lo largo de un conjunto. Nos permite ver cómo se suman las frecuencias en cada clase o intervalo y facilita la identificación de **percentiles** y valores acumulativos importantes.
#
# - **Ventajas de la Ojiva**:
#
#   - Permite identificar fácilmente los **percentiles** de la distribución.
#   - Visualiza cómo se **acumulan los datos** a medida que avanzamos por los valores.
#   - Es útil para comparar con otros tipos de gráficos, como el **histograma**, para obtener una visión más completa de la distribución.
# - **Limitaciones**:
#
#   - La ojiva no muestra la **distribución detallada** dentro de los intervalos como lo hace un histograma, por lo que no es ideal si queremos ver cómo se distribuyen los datos dentro de cada clase.
#
# Al igual que el histograma, la **ojiva** es una herramienta fundamental para el análisis exploratorio de datos y es especialmente útil cuando se quiere entender cómo los datos se acumulan a lo largo de un conjunto.

# %% [markdown]
# ### 5.4 **Indicadores de Forma: Asimetría y Curtosis**
#
# #### **Teoría**
#
# Los **indicadores de forma** nos permiten conocer cómo es la **distribución** de nuestros datos en términos de su **asimetría** y **curtosis**. Estas métricas son esenciales para entender si una distribución se desvía de la simetría o tiene características extremas como colas largas o picos muy marcados. Entender estos indicadores nos ayuda a interpretar mejor los datos y detectar comportamientos atípicos.
#
# ---
#
# #### **Asimetría (Skewness)**
#
# La **asimetría** mide la **simetría** de una distribución:
#
# - **Asimetría positiva**: La distribución tiene una **cola más larga a la derecha**. Esto significa que hay algunos valores inusualmente altos que hacen que la cola derecha se alargue.
# - **Asimetría negativa**: La distribución tiene una **cola más larga a la izquierda**, lo que indica que hay valores inusualmente bajos.
# - **Asimetría cero (0)**: La distribución es **perfectamente simétrica**.
#
# #### **Curtosis**
#
# La **curtosis** mide la **forma del pico** de una distribución:
#
# - **Curtosis positiva**: La distribución tiene un pico más alto y colas más gruesas. Esto significa que los datos están muy concentrados alrededor de la media y hay más probabilidades de valores extremos en las colas.
# - **Curtosis negativa**: La distribución es más **plana**, con menos datos en el centro y colas más delgadas, lo que significa que hay menos valores extremos.
#
# ---
#
# ### **Intuición Visual y Ejemplificación**
#
# Para entender mejor estos conceptos, vamos a comparar distribuciones con **asimetría** y **curtosis** en diferentes escenarios. Primero calcularemos las métricas y luego visualizaremos las distribuciones.
#
# ---
#
# ### **Ejemplo en Python: Asimetría y Curtosis**
#
# A continuación, vamos a generar distribuciones que exhiben diferentes tipos de asimetría y curtosis para visualizar cómo estos indicadores afectan las formas de las distribuciones.
#
# #### **Paso 1: Generar ejemplos de distribuciones**
#
# Vamos a crear diferentes conjuntos de datos que tengan:
#
# - **Distribución normal (simétrica)**
# - **Distribución con asimetría positiva**
# - **Distribución con asimetría negativa**
# - **Distribución con curtosis positiva (picos altos)**
# - **Distribución con curtosis negativa (picos bajos)**
#
# #### **Código**:

# %%
import numpy as np
import matplotlib.pyplot as plt
from scipy.stats import skew, kurtosis

# Generar distribuciones
np.random.seed(42)
data_normal = np.random.normal(0, 1, 1000)  # Distribución normal
data_skew_pos = np.random.exponential(scale=2, size=1000)  # Asimetría positiva
data_skew_neg = -np.random.exponential(scale=2, size=1000)  # Asimetría negativa
data_kurt_high = np.random.laplace(loc=0, scale=0.5, size=1000)  # Curtosis positiva (pico alto)
data_kurt_low = np.random.uniform(-3, 3, 1000)  # Curtosis negativa (pico bajo)

# Calcular asimetría y curtosis
skew_normal_value = skew(data_normal)
kurt_normal_value = kurtosis(data_normal)
skew_pos_value = skew(data_skew_pos)
kurt_pos_value = kurtosis(data_skew_pos)
skew_neg_value = skew(data_skew_neg)
kurt_neg_value = kurtosis(data_skew_neg)
kurt_high_value = kurtosis(data_kurt_high)
kurt_low_value = kurtosis(data_kurt_low)

# Crear la figura y los subgráficos en una sola columna
fig, axs = plt.subplots(5, 1, figsize=(8, 30))  # Aumentar más el tamaño de la figura para más espacio

# Configurar espaciado entre gráficos
plt.subplots_adjust(hspace=0.5)

# Distribución normal
axs[0].hist(data_normal, bins=30, color='lightblue', edgecolor='black')
axs[0].set_title(f"Distribución Normal\nAsimetría: {skew_normal_value:.2f}, Curtosis: {kurt_normal_value:.2f}")
axs[0].annotate("Interpretación: La distribución es simétrica, con un pico moderado y colas normales.\n"
                "La asimetría y curtosis son cercanas a 0, lo que indica una distribución normal estándar.",
                xy=(0.5, -0.25), xycoords='axes fraction', ha='center', fontsize=10)

# Asimetría positiva
axs[1].hist(data_skew_pos, bins=30, color='lightcoral', edgecolor='black')
axs[1].set_title(f"Asimetría Positiva\nAsimetría: {skew_pos_value:.2f}, Curtosis: {kurt_pos_value:.2f}")
axs[1].annotate("Interpretación: La distribución tiene una cola larga a la derecha, lo que indica valores altos extremos.\n"
                "La curtosis alta sugiere un pico pronunciado y colas gruesas.",
                xy=(0.5, -0.25), xycoords='axes fraction', ha='center', fontsize=10)

# Asimetría negativa
axs[2].hist(data_skew_neg, bins=30, color='lightgreen', edgecolor='black')
axs[2].set_title(f"Asimetría Negativa\nAsimetría: {skew_neg_value:.2f}, Curtosis: {kurt_neg_value:.2f}")
axs[2].annotate("Interpretación: La distribución tiene una cola larga a la izquierda, con valores bajos extremos.\n"
                "El pico es elevado, y las colas son más gruesas de lo habitual.",
                xy=(0.5, -0.25), xycoords='axes fraction', ha='center', fontsize=10)

# Curtosis alta (pico alto)
axs[3].hist(data_kurt_high, bins=30, color='deepskyblue', edgecolor='black')
axs[3].set_title(f"Curtosis Alta (Pico Alto)\nAsimetría: {skew(data_kurt_high):.2f}, Curtosis: {kurt_high_value:.2f}")
axs[3].annotate("Interpretación: La distribución es simétrica pero tiene un pico muy alto y colas gruesas.\n"
                "Los datos están muy concentrados alrededor de la media, pero hay valores extremos.",
                xy=(0.5, -0.25), xycoords='axes fraction', ha='center', fontsize=10)

# Curtosis baja (pico bajo)
axs[4].hist(data_kurt_low, bins=30, color='purple', edgecolor='black')
axs[4].set_title(f"Curtosis Baja (Pico Bajo)\nAsimetría: {skew(data_kurt_low):.2f}, Curtosis: {kurt_low_value:.2f}")
axs[4].annotate("Interpretación: La distribución es más plana y los datos están dispersos de manera uniforme.\n"
                "Las colas son delgadas, lo que sugiere menos valores extremos.",
                xy=(0.5, -0.25), xycoords='axes fraction', ha='center', fontsize=10)

# Mostrar la gráfica
plt.show()

# %% [markdown]
# **Casos Extremos y la Intuición detrás de Asimetría y Curtosis**
#
# #### **Asimetría**:
#
# 1. **Positiva**: Imagine una situación en la que la mayoría de los estudiantes tienen calificaciones cercanas a 70, pero algunos pocos tienen calificaciones extremadamente altas (95 o más). Esto crea una cola hacia la derecha.
# 2. **Negativa**: Si la mayoría de los estudiantes tienen calificaciones altas, pero algunos pocos tienen calificaciones muy bajas, la distribución tendrá una cola a la izquierda.
#
# #### **Curtosis**:
#
# 1. **Alta Curtosis**: Se asocia con la probabilidad de observar valores extremos más alta que en una distribución normal. Esto es útil en situaciones como mercados financieros, donde las crisis pueden generar picos agudos de valores extremos (por ejemplo, grandes caídas o subidas en los precios).
# 2. **Baja Curtosis**: Si los datos están más dispersos y no tienen picos extremos, como por ejemplo, en el tamaño de los zapatos de una población general, la curtosis será baja.
#
# ### **Interpretación Final**
#
# - **Asimetría** nos ayuda a entender si nuestros datos están más inclinados hacia valores bajos o altos.
# - **Curtosis** nos indica si los datos están concentrados alrededor de la media o si tienden a tener más valores extremos.
#
# Estos **indicadores de forma** son esenciales para interpretar la **distribución** de un conjunto de datos, lo que puede ser clave en muchos análisis estadísticos, especialmente cuando se espera que los datos se distribuyan de manera **normal** pero se observa que tienen **asimetría** o **colas más gruesas** de lo esperado.
#
# ---
#
# ### **Conclusión del Resumen de Información**
#
# A través de herramientas como **tablas de frecuencias**, **histogramas**, **ojivas** y los **indicadores de forma**, podemos obtener una comprensión profunda de cómo están distribuidos nuestros datos y cómo se comportan en términos de **frecuencia**, **tendencia central** y **forma**.
#
# - La **tabla de frecuencias** nos ofrece una descripción exacta de la frecuencia de los valores individuales.
# - El **histograma** proporciona una visión gráfica de la distribución general de los datos, útil para identificar patrones.
# - La **ojiva** nos permite ver cómo se acumulan los datos a medida que avanzamos a través de la escala.
# - Finalmente, las medidas de **asimetría** y **curtosis** nos dan una idea de la forma de la distribución en términos de simetría y "puntiagudez".
#
# Cada una de estas herramientas es esencial para un análisis completo de los datos.

# %% [markdown]
# # 6. **Diagrama de Cajas y Brazos**
#
# #### **Teoría**:
#
# El **diagrama de cajas y brazos** (o **boxplot**) es una herramienta gráfica que permite representar de manera compacta la **distribución** de un conjunto de datos, resaltando puntos clave como la **mediana**, los **cuartiles** y los **valores atípicos**. Este diagrama es muy útil para identificar la **dispersión**, **asimetría** y la **presencia de outliers** (valores atípicos).
#
# #### **Elementos Clave del Diagrama de Cajas**:
#
# 1. **Caja**: La caja representa el **rango intercuartílico (IQR)**, es decir, el rango entre el primer cuartil (**Q1**, el percentil 25) y el tercer cuartil (**Q3**, el percentil 75). Este rango contiene el **50% central** de los datos.
#
# 2. **Línea en la caja**: Representa la **mediana** (el percentil 50). Es el valor que divide la mitad inferior de la mitad superior de los datos.
#
# 3. **Brazos (o "bigotes")**: Los brazos del diagrama se extienden hasta los valores que están dentro de 1.5 veces el IQR desde los cuartiles (Q1 - 1.5 * IQR, Q3 + 1.5 * IQR). Todo valor fuera de este rango se considera **atípico**.
#
# 4. **Puntos atípicos**: Estos son los valores que caen fuera del rango de los brazos y son indicados por puntos individuales fuera de los "bigotes". Indican **outliers** o **valores atípicos**.
#
#
# #### **Ejemplo de Código en Python**:
#
# A continuación se presenta un ejemplo para visualizar un diagrama de cajas utilizando **Python**:

# %%
import matplotlib.pyplot as plt
import numpy as np

# Datos de ejemplo (calificaciones de un grupo de estudiantes)
data = [85, 90, 78, 92, 88, 76, 95, 89, 85, 100, 45]  # Incluyendo un valor atípico (45)

# Crear la figura
fig, ax = plt.subplots(figsize=(10, 6))

# Crear el diagrama de cajas
ax.boxplot(data, vert=False, patch_artist=True, boxprops=dict(facecolor='lightblue'))  # Gráfico de cajas horizontal

# Añadir los puntos individuales debajo del diagrama de cajas (distribución unidimensional)
y = np.ones(len(data))  # Todos los puntos en la misma fila (en el eje y)


# Ajustes adicionales
ax.set_yticks([])  # Ocultar el eje y ya que solo necesitamos el eje x
ax.set_xlabel('Calificaciones')
ax.set_title('Diagrama de Cajas y Distribución de Datos (Dot Plot)', fontsize=14)
ax.grid(True, axis='x')  # Mostrar una cuadrícula en el eje x

# Mostrar la gráfica
plt.show()

# %%
import matplotlib.pyplot as plt
import numpy as np

# Datos de ejemplo (calificaciones de un grupo de estudiantes)
data = [85, 90, 78, 92, 88, 76, 95, 89, 85, 100, 45]  # Incluyendo un valor atípico (45)

# Crear la figura
fig, ax = plt.subplots(figsize=(10, 6))

# Crear el diagrama de cajas
ax.boxplot(data, vert=False, patch_artist=True, boxprops=dict(facecolor='lightblue'))  # Gráfico de cajas horizontal

# Añadir los puntos individuales debajo del diagrama de cajas (distribución unidimensional)
y = np.ones(len(data))  # Todos los puntos en la misma fila (en el eje y)

ax.plot(data, y - 0.1, 'bo', alpha=0.6, label='Datos individuales')  # Colocar los puntos ligeramente debajo del boxplot


# Ajustes adicionales
ax.set_yticks([])  # Ocultar el eje y ya que solo necesitamos el eje x
ax.set_xlabel('Calificaciones')
ax.set_title('Diagrama de Cajas y Distribución de Datos (Dot Plot)', fontsize=14)
ax.grid(True, axis='x')  # Mostrar una cuadrícula en el eje x

# Mostrar la gráfica
plt.show()

# %% [markdown]
# #### **Visualización**:
#
# Al ejecutar este código, verás una gráfica similar a la siguiente:
#
# 1. **Caja central**: Representa los valores comprendidos entre el primer cuartil (**Q1**) y el tercer cuartil (**Q3**). Dentro de esta caja se encuentra el **50% central** de los datos.
# 2. **Mediana**: Está indicada por una línea dentro de la caja. Este es el valor central de la distribución.
# 3. **Brazos**: Se extienden hasta los puntos que se encuentran dentro de 1.5 veces el rango intercuartílico (IQR).
# 4. **Valores atípicos**: En este caso, el valor **45** sería un outlier, ya que cae fuera del rango esperado de los datos.
#
# #### **Interpretación del Diagrama**:
#
# - Si la **caja** es muy alargada, significa que hay mucha **dispersión** en los datos.
# - La **posición de la mediana** dentro de la caja puede mostrar **asimetría**. Si está más cerca de Q1 o Q3, puede indicar que los datos no están distribuidos de manera uniforme.
# - La **longitud de los brazos** indica el **rango** de los datos. Brazos muy largos sugieren datos muy dispersos, mientras que brazos cortos indican una menor dispersión.
# - **Outliers**: Los valores atípicos se identifican como puntos individuales fuera del rango de los brazos y pueden dar información importante sobre posibles errores o comportamientos atípicos en los datos.
#
# #### **Aplicación del Diagrama de Cajas**:
#
# Este tipo de gráfico es especialmente útil cuando quieres:
#
# - Comparar distribuciones de varios conjuntos de datos simultáneamente.
# - Identificar rápidamente valores atípicos.
# - Evaluar la **asimetría** y **dispersión** de los datos de manera visual.
#
# ### **Conclusión**:
#
# El **diagrama de cajas y brazos** es una herramienta visual poderosa que permite resumir la información estadística clave de un conjunto de datos. A través de la representación de los cuartiles, la mediana y los outliers, facilita la comprensión de la **distribución** de los datos de manera rápida y efectiva, haciéndolo ideal para análisis exploratorios de datos.
